# %% [markdown]
# # Import

# %% [markdown]
# ## Modules

# %%
import sys
from datetime import timedelta, datetime
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PoissonRegressor

# %% [markdown]
# Setup figure plot settings

# %%
# %config InlineBackend.figure_format = 'retina'
az.style.use("arviz-darkgrid")
sns.set_palette("deep")

# %% [markdown]
#  Setup paths to import scripts

# %%
PROJECT_ROOT = Path.cwd().parent.resolve()
sys.path.append(str(PROJECT_ROOT))

# %% [markdown]
# ## Scripts

# %%
from src.data.make_dataset import get_cases_data, to_datetime, subset_latest_outbreak, get_daily_cases_stats

# %% [markdown]
# ## Data

# %%
raw_cases_data = get_cases_data()

# %% [markdown]
# ## Audit

# %%
raw_cases_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9866 entries, 0 to 9865
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   notification_date           9866 non-null   object
#  1   postcode                    9061 non-null   object
#  2   likely_source_of_infection  9866 non-null   object
#  3   lhd_2010_code               9050 non-null   object
#  4   lhd_2010_name               9050 non-null   object
#  5   lga_code19                  9050 non-null   float64
#  6   lga_name19                  9050 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 539.7+ KB

# %%
raw_cases_data.head()
# Out:
#   notification_date postcode likely_source_of_infection lhd_2010_code  \
# 0        2020-01-25     2134                   Overseas          X700
# 1        2020-01-25     2121                   Overseas          X760
# 2        2020-01-25     2071                   Overseas          X760
# 3        2020-01-27     2033                   Overseas          X720
# 4        2020-03-01     2077                   Overseas          X760
#
#           lhd_2010_name  lga_code19       lga_name19
# 0                Sydney     11300.0      Burwood (A)
# 1       Northern Sydney     16260.0   Parramatta (C)
# 2       Northern Sydney     14500.0  Ku-ring-gai (A)
# 3  South Eastern Sydney     16550.0     Randwick (C)
# 4       Northern Sydney     14000.0      Hornsby (A)

# %% [markdown]
# # Preprocess Raw Data

# %%
# Transform column notification_date to datetime
raw_cases_data = to_datetime('notification_date', raw_cases_data)

# Subset data to the latest outbreak
interim_data = subset_latest_outbreak('2021-06-01', 'Overseas', raw_cases_data)

# Aggregate number of cases by day
data = get_daily_cases_stats(interim_data)
data
# Out:
#    notification_date  Daily Number of Cases  Pct Change  Cumsum  \
# 0         2021-06-16                      3         NaN       3
# 1         2021-06-17                      1   -0.666667       4
# 2         2021-06-18                      2    1.000000       6
# 3         2021-06-19                      1   -0.500000       7
# 4         2021-06-20                      2    1.000000       9
# 5         2021-06-21                      5    1.500000      14
# 6         2021-06-22                     17    2.400000      31
# 7         2021-06-23                     12   -0.294118      43
# 8         2021-06-24                     21    0.750000      64
# 9         2021-06-25                     28    0.333333      92
# 10        2021-06-26                     25   -0.107143     117
# 11        2021-06-27                     21   -0.160000     138
# 12        2021-06-28                     14   -0.333333     152
# 13        2021-06-29                     23    0.642857     175
# 14        2021-06-30                     30    0.304348     205
# 15        2021-07-01                     27   -0.100000     232
# 16        2021-07-02                     34    0.259259     266
# 17        2021-07-03                     22   -0.352941     288
# 18        2021-07-04                     31    0.409091     319
# 19        2021-07-05                     16   -0.483871     335
# 20        2021-07-06                     33    1.062500     368
# 21        2021-07-07                     36    0.090909     404
# 22        2021-07-08                     45    0.250000     449
# 23        2021-07-09                     49    0.088889     498
# 24        2021-07-10                    103    1.102041     601
# 25        2021-07-11                    114    0.106796     715
# 26        2021-07-12                     72   -0.368421     787
# 27        2021-07-13                     88    0.222222     875
# 28        2021-07-14                     75   -0.147727     950
# 29        2021-07-15                    100    0.333333    1050
# 30        2021-07-16                    109    0.090000    1159
# 31        2021-07-17                     95   -0.128440    1254
# 32        2021-07-18                    111    0.168421    1365
# 33        2021-07-19                     65   -0.414414    1430
# 34        2021-07-20                    106    0.630769    1536
# 35        2021-07-21                    142    0.339623    1678
# 36        2021-07-22                    141   -0.007042    1819
# 37        2021-07-23                    151    0.070922    1970
# 38        2021-07-24                    142   -0.059603    2112
# 39        2021-07-25                    168    0.183099    2280
# 40        2021-07-26                    140   -0.166667    2420
# 41        2021-07-27                    162    0.157143    2582
# 42        2021-07-28                    259    0.598765    2841
# 43        2021-07-29                    183   -0.293436    3024
# 44        2021-07-30                    200    0.092896    3224
# 45        2021-07-31                    248    0.240000    3472
# 46        2021-08-01                    194   -0.217742    3666
# 47        2021-08-02                    209    0.077320    3875
# 48        2021-08-03                    242    0.157895    4117
# 49        2021-08-04                    192   -0.206612    4309
#
#     Daily Difference  Growth Factor  Weekly Rolling Average  \
# 0                NaN            NaN                     NaN
# 1               -2.0            NaN                     NaN
# 2                1.0      -0.500000                     NaN
# 3               -1.0      -1.000000                     NaN
# 4                1.0      -1.000000                     NaN
# 5                3.0       3.000000                     NaN
# 6               12.0       4.000000                     4.0
# 7               -5.0      -0.416667                     6.0
# 8                9.0      -1.800000                     9.0
# 9                7.0       0.777778                    12.0
# 10              -3.0      -0.428571                    16.0
# 11              -4.0       1.333333                    18.0
# 12              -7.0       1.750000                    20.0
# 13               9.0      -1.285714                    21.0
# 14               7.0       0.777778                    23.0
# 15              -3.0      -0.428571                    24.0
# 16               7.0      -2.333333                    25.0
# 17             -12.0      -1.714286                    24.0
# 18               9.0      -0.750000                    26.0
# 19             -15.0      -1.666667                    26.0
# 20              17.0      -1.133333                    28.0
# 21               3.0       0.176471                    28.0
# 22               9.0       3.000000                    31.0
# 23               4.0       0.444444                    33.0
# 24              54.0      13.500000                    45.0
# 25              11.0       0.203704                    57.0
# 26             -42.0      -3.818182                    65.0
# 27              16.0      -0.380952                    72.0
# 28             -13.0      -0.812500                    78.0
# 29              25.0      -1.923077                    86.0
# 30               9.0       0.360000                    94.0
# 31             -14.0      -1.555556                    93.0
# 32              16.0      -1.142857                    93.0
# 33             -46.0      -2.875000                    92.0
# 34              41.0      -0.891304                    94.0
# 35              36.0       0.878049                   104.0
# 36              -1.0      -0.027778                   110.0
# 37              10.0     -10.000000                   116.0
# 38              -9.0      -0.900000                   123.0
# 39              26.0      -2.888889                   131.0
# 40             -28.0      -1.076923                   141.0
# 41              22.0      -0.785714                   149.0
# 42              97.0       4.409091                   166.0
# 43             -76.0      -0.783505                   172.0
# 44              17.0      -0.223684                   179.0
# 45              48.0       2.823529                   194.0
# 46             -54.0      -1.125000                   198.0
# 47              15.0      -0.277778                   208.0
# 48              33.0       2.200000                   219.0
# 49             -50.0      -1.515152                   210.0
#
#     Weekly Average CumSum  Epidemiological Days
# 0                     NaN                 -24.0
# 1                     NaN                 -23.0
# 2                     NaN                 -22.0
# 3                     NaN                 -21.0
# 4                     NaN                 -20.0
# 5                     NaN                 -19.0
# 6                     4.0                 -18.0
# 7                    10.0                 -17.0
# 8                    19.0                 -16.0
# 9                    31.0                 -15.0
# 10                   47.0                 -14.0
# 11                   65.0                 -13.0
# 12                   85.0                 -12.0
# 13                  106.0                 -11.0
# 14                  129.0                 -10.0
# 15                  153.0                  -9.0
# 16                  178.0                  -8.0
# 17                  202.0                  -7.0
# 18                  228.0                  -6.0
# 19                  254.0                  -5.0
# 20                  282.0                  -4.0
# 21                  310.0                  -3.0
# 22                  341.0                  -2.0
# 23                  374.0                  -1.0
# 24                  419.0                   0.0
# 25                  476.0                   1.0
# 26                  541.0                   2.0
# 27                  613.0                   3.0
# 28                  691.0                   4.0
# 29                  777.0                   5.0
# 30                  871.0                   6.0
# 31                  964.0                   7.0
# 32                 1057.0                   8.0
# 33                 1149.0                   9.0
# 34                 1243.0                  10.0
# 35                 1347.0                  11.0
# 36                 1457.0                  12.0
# 37                 1573.0                  13.0
# 38                 1696.0                  14.0
# 39                 1827.0                  15.0
# 40                 1968.0                  16.0
# 41                 2117.0                  17.0
# 42                 2283.0                  18.0
# 43                 2455.0                  19.0
# 44                 2634.0                  20.0
# 45                 2828.0                  21.0
# 46                 3026.0                  22.0
# 47                 3234.0                  23.0
# 48                 3453.0                  24.0
# 49                 3663.0                  25.0

# %% [markdown]
# ## Split Predictor and Target Columns

# %% [markdown]
# Get initial number of cases, based on weekly rolling mean

# %%
mask = data['Epidemiological Days'] == 0
initial_number_of_cases = data.loc[mask, 'Weekly Rolling Average'].values[0]
print(f"Initial number of cases: {initial_number_of_cases}")
# Out:
# Initial number of cases: 45.0

# %% [markdown]
# Split predictor and target columns

# %%
mask = data['Epidemiological Days'] >= 0
X = data.loc[mask, ["Epidemiological Days", 'Daily Number of Cases', 'Pct Change']]
y = data.loc[mask, "Weekly Rolling Average"]

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# Train-test split

# %%
train_size = 0.7
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=train_size)

# %% [markdown]
# Setting up initial parameters for Bayesian modelling

# %%
daily_number_of_cases_std = X_train['Daily Number of Cases'].std()
average_pct_change = X_train['Pct Change'].mean()
std_pct_change = X_train['Pct Change'].std()

print(f"Daily number of cases std: {daily_number_of_cases_std}")
print(f"Average percenntage change: {average_pct_change}")
print(f"Standard deviation of percentage change: {std_pct_change}")
# Out:
# Daily number of cases std: 48.96283771519154
# Average percenntage change: 0.10203126654564262
# Standard deviation of percentage change: 0.35077546910006835

# %% [markdown]
# Selecting only epidemiological days for predictor and define datasets as `np.ndarray` objects

# %%
X_train = X_train["Epidemiological Days"].values
y_train = y_train.values
X_test = X_test["Epidemiological Days"].values
y_test = y_test.values

X = X["Epidemiological Days"].values
y = y.values

# %% [markdown]
# ## Train Model
